# %%
import pandas as pd

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Hp\Desktop\Graph Analytics Project\Dataset\social_influence_dataset.csv")

df.head()
# Out:
#   user_id  followers  following  posts  likes_received  comments_received  \
# 0  U00001      44671        733   3070         1781610              27334
# 1  U00002     386989       1197   1768         3995775              91208
# 2  U00003     327303       5957   4453         3041420             166932
# 3  U00004     219467       5696    375         4940929             134407
# 4  U00005     216535       5553   1381         3878565              56525
#
#    mentions  shares  account_age_days region  engagement_rate  \
# 0      6848   25950              4627  South          4294.14
# 1      6979   47510              2590  North          1150.37
# 2      3606   14320               685   East          1184.24
# 3      9217   32757              3652   East          2557.53
# 4      8462   36673              2404  South              NaN
#
#    degree_centrality  betweenness_centrality  influence_score
# 0              0.570                   0.143             17.4
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12150 entries, 0 to 12149
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   user_id                 12150 non-null  str
#  1   followers               12150 non-null  int64
#  2   following               12150 non-null  int64
#  3   posts                   12150 non-null  int64
#  4   likes_received          12150 non-null  int64
#  5   comments_received       12150 non-null  int64
#  6   mentions                12150 non-null  int64
#  7   shares                  12150 non-null  int64
#  8   account_age_days        12150 non-null  int64
#  9   region                  12150 non-null  str
#  10  engagement_rate         11844 non-null  float64
#  11  degree_centrality       12150 non-null  float64
#  12  betweenness_centrality  12150 non-null  float64
#  13  influence_score         12150 non-null  float64
# dtypes: float64(4), int64(8), str(2)
# ...

# %%
df.isnull().sum()
# Out:
# user_id                     0
# followers                   0
# following                   0
# posts                       0
# likes_received              0
# comments_received           0
# mentions                    0
# shares                      0
# account_age_days            0
# region                      0
# engagement_rate           306
# degree_centrality           0
# betweenness_centrality      0
# influence_score             0
# dtype: int64

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)
# Out:
#       user_id  followers  following  posts  likes_received  comments_received  \
# 0      U00001      44671        733   3070         1781610              27334
# 1      U00002     386989       1197   1768         3995775              91208
# 2      U00003     327303       5957   4453         3041420             166932
# 3      U00004     219467       5696    375         4940929             134407
# 4      U00005     216535       5553   1381         3878565              56525
# ...       ...        ...        ...    ...             ...                ...
# 12145  U10859      12293       6020   2462          654585              91206
# 12146  U02980     358610       9471    940         4838120                420
# 12147  U00509     134382       5807   2087          406020             148298
# 12148  U00546      26738        267    690         1914891             130049
# 12149  U00801     150998       3153    261         1739043              60191
#
# ...

# %%
df.isnull().sum()
# Out:
# user_id                   0
# followers                 0
# following                 0
# posts                     0
# likes_received            0
# comments_received         0
# mentions                  0
# shares                    0
# account_age_days          0
# region                    0
# engagement_rate           0
# degree_centrality         0
# betweenness_centrality    0
# influence_score           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(149)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv(
    r"C:\Users\Hp\Desktop\Graph Analytics Project\Results\cleaned_dataset.csv",
    index=False
)

# %%
df.shape
# Out:
# (12001, 14)

# %%
import matplotlib.pyplot as plt

top10 = df.nlargest(10, 'influence_score')

plt.figure(figsize=(10,5))
plt.bar(top10['user_id'], top10['influence_score'])
plt.title('Top 10 Influential Users')
plt.xlabel('User ID')
plt.ylabel('Influence Score')
plt.xticks(rotation=45)

plt.show()

# %%
plt.savefig(
    r"C:\Users\Hp\Desktop\Graph Analytics Project\Results\top10_influencers.png",
    bbox_inches='tight'
)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (12001, 14)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (12001, 14)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Hp'

# %%
import os

os.listdir("OneDrive/Desktop")
# Out:
# ['Antigravity',
#  'Antigravity IDE.lnk',
#  'app',
#  'desktop.ini',
#  'Framer.lnk',
#  'Graph Analytics Project',
#  'restaurant web']

# %%
os.listdir("OneDrive/Desktop/Graph Analytics Project")
# Out:
# ['Dataset', 'Notebook', 'Report', 'Results', 'Scripts']

# %%
os.listdir("OneDrive/Desktop/Graph Analytics Project/Dataset")
# Out:
# ['social_influence_dataset.csv']

# %%
os.path.abspath("OneDrive/Desktop/Graph Analytics Project/Dataset/social_influence_dataset.csv")
# Out:
# 'C:\\Users\\Hp\\OneDrive\\Desktop\\Graph Analytics Project\\Dataset\\social_influence_dataset.csv'

# %%
import pandas as pd

df = pd.read_csv(
    "OneDrive/Desktop/Graph Analytics Project/Dataset/social_influence_dataset.csv"
)

df.head()
# Out:
#   user_id  followers  following  posts  likes_received  comments_received  \
# 0  U00001      44671        733   3070         1781610              27334
# 1  U00002     386989       1197   1768         3995775              91208
# 2  U00003     327303       5957   4453         3041420             166932
# 3  U00004     219467       5696    375         4940929             134407
# 4  U00005     216535       5553   1381         3878565              56525
#
#    mentions  shares  account_age_days region  engagement_rate  \
# 0      6848   25950              4627  South          4294.14
# 1      6979   47510              2590  North          1150.37
# 2      3606   14320               685   East          1184.24
# 3      9217   32757              3652   East          2557.53
# 4      8462   36673              2404  South              NaN
#
#    degree_centrality  betweenness_centrality  influence_score
# 0              0.570                   0.143             17.4
# ...

# %%
df.shape
# Out:
# (12150, 14)

# %%
df_processed = df.copy()

# %%
df_processed.head()
# Out:
#   user_id  followers  following  posts  likes_received  comments_received  \
# 0  U00001      44671        733   3070         1781610              27334
# 1  U00002     386989       1197   1768         3995775              91208
# 2  U00003     327303       5957   4453         3041420             166932
# 3  U00004     219467       5696    375         4940929             134407
# 4  U00005     216535       5553   1381         3878565              56525
#
#    mentions  shares  account_age_days region  engagement_rate  \
# 0      6848   25950              4627  South          4294.14
# 1      6979   47510              2590  North          1150.37
# 2      3606   14320               685   East          1184.24
# 3      9217   32757              3652   East          2557.53
# 4      8462   36673              2404  South              NaN
#
#    degree_centrality  betweenness_centrality  influence_score
# 0              0.570                   0.143             17.4
# ...

# %%
numerical_cols = df_processed.select_dtypes(
    include=['int64', 'float64']
).columns

categorical_cols = df_processed.select_dtypes(
    include=['object']
).columns

print("Numerical Columns:")
print(numerical_cols)

print("\nCategorical Columns:")
print(categorical_cols)
# Out:
# Numerical Columns:
# Index(['followers', 'following', 'posts', 'likes_received',
#        'comments_received', 'mentions', 'shares', 'account_age_days',
#        'engagement_rate', 'degree_centrality', 'betweenness_centrality',
#        'influence_score'],
#       dtype='str')
#
# Categorical Columns:
# Index(['user_id', 'region'], dtype='str')
# C:\Users\Hp\AppData\Local\Temp\ipykernel_21676\4008938091.py:5: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_cols = df_processed.select_dtypes(

# %%
df_processed.describe()
# Out:
#           followers     following         posts  likes_received  \
# count  1.215000e+04  12150.000000  12150.000000    1.215000e+04
# mean   3.534820e+05   4983.389383   2509.723292    2.501367e+06
# std    1.867712e+06   2892.355496   1448.369847    1.448069e+06
# min    5.000000e+01     10.000000      0.000000    9.600000e+01
# 25%    1.249000e+05   2477.750000   1244.000000    1.246178e+06
# 50%    2.496145e+05   4987.000000   2522.500000    2.510190e+06
# 75%    3.740302e+05   7468.750000   3758.750000    3.761432e+06
# max    4.970390e+07   9999.000000   4999.000000    4.999912e+06
#
#        comments_received      mentions        shares  account_age_days  \
# count       12150.000000  12150.000000  12150.000000      12150.000000
# mean        99987.376543   4979.541564  25182.342140       2499.163374
# std         57360.075211   2886.584149  14455.018245       1434.803891
# min             0.000000      0.000000      6.000000         31.000000
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.hist(df_processed['influence_score'], bins=30)

plt.title('Distribution of Influence Score')
plt.xlabel('Influence Score')
plt.ylabel('Frequency')

plt.show()

# %%
top10 = df_processed.nlargest(10, 'influence_score')

top10[['user_id', 'influence_score']]
# Out:
#       user_id  influence_score
# 5012   U05013             62.1
# 285    U00286             62.0
# 10144  U10145             62.0
# 5106   U05107             61.8
# 5937   U05938             61.8
# 8575   U08576             61.8
# 2835   U02836             60.7
# 8454   U08455             60.7
# 9083   U09084             60.7
# 5293   U05294             60.6

# %%
df_processed.describe()
# Out:
#           followers     following         posts  likes_received  \
# count  1.215000e+04  12150.000000  12150.000000    1.215000e+04
# mean   3.534820e+05   4983.389383   2509.723292    2.501367e+06
# std    1.867712e+06   2892.355496   1448.369847    1.448069e+06
# min    5.000000e+01     10.000000      0.000000    9.600000e+01
# 25%    1.249000e+05   2477.750000   1244.000000    1.246178e+06
# 50%    2.496145e+05   4987.000000   2522.500000    2.510190e+06
# 75%    3.740302e+05   7468.750000   3758.750000    3.761432e+06
# max    4.970390e+07   9999.000000   4999.000000    4.999912e+06
#
#        comments_received      mentions        shares  account_age_days  \
# count       12150.000000  12150.000000  12150.000000      12150.000000
# mean        99987.376543   4979.541564  25182.342140       2499.163374
# std         57360.075211   2886.584149  14455.018245       1434.803891
# min             0.000000      0.000000      6.000000         31.000000
# ...

# %%
top10 = df_processed.nlargest(10, 'influence_score')
top10[['user_id', 'influence_score']]
# Out:
#       user_id  influence_score
# 5012   U05013             62.1
# 285    U00286             62.0
# 10144  U10145             62.0
# 5106   U05107             61.8
# 5937   U05938             61.8
# 8575   U08576             61.8
# 2835   U02836             60.7
# 8454   U08455             60.7
# 9083   U09084             60.7
# 5293   U05294             60.6

# %%
import pandas as pd

df = pd.read_csv(
    "OneDrive/Desktop/Graph Analytics Project/Dataset/social_influence_dataset.csv"
)

df.head()
# Out:
#   user_id  followers  following  posts  likes_received  comments_received  \
# 0  U00001      44671        733   3070         1781610              27334
# 1  U00002     386989       1197   1768         3995775              91208
# 2  U00003     327303       5957   4453         3041420             166932
# 3  U00004     219467       5696    375         4940929             134407
# 4  U00005     216535       5553   1381         3878565              56525
#
#    mentions  shares  account_age_days region  engagement_rate  \
# 0      6848   25950              4627  South          4294.14
# 1      6979   47510              2590  North          1150.37
# 2      3606   14320               685   East          1184.24
# 3      9217   32757              3652   East          2557.53
# 4      8462   36673              2404  South              NaN
#
#    degree_centrality  betweenness_centrality  influence_score
# 0              0.570                   0.143             17.4
# ...

# %%
df_processed = df.copy()

# %%
top10 = df_processed.nlargest(10, 'influence_score')

# %%
df.head()
# Out:
#   user_id  followers  following  posts  likes_received  comments_received  \
# 0  U00001      44671        733   3070         1781610              27334
# 1  U00002     386989       1197   1768         3995775              91208
# 2  U00003     327303       5957   4453         3041420             166932
# 3  U00004     219467       5696    375         4940929             134407
# 4  U00005     216535       5553   1381         3878565              56525
#
#    mentions  shares  account_age_days region  engagement_rate  \
# 0      6848   25950              4627  South          4294.14
# 1      6979   47510              2590  North          1150.37
# 2      3606   14320               685   East          1184.24
# 3      9217   32757              3652   East          2557.53
# 4      8462   36673              2404  South              NaN
#
#    degree_centrality  betweenness_centrality  influence_score
# 0              0.570                   0.143             17.4
# ...

# %%
df_processed.shape
# Out:
# (12150, 14)

# %%
top10 = df_processed.nlargest(10, 'influence_score')

top10[['user_id', 'influence_score']]
# Out:
#       user_id  influence_score
# 5012   U05013             62.1
# 285    U00286             62.0
# 10144  U10145             62.0
# 5106   U05107             61.8
# 5937   U05938             61.8
# 8575   U08576             61.8
# 2835   U02836             60.7
# 8454   U08455             60.7
# 9083   U09084             60.7
# 5293   U05294             60.6

# %%
top10[['user_id', 'influence_score']]
# Out:
#       user_id  influence_score
# 5012   U05013             62.1
# 285    U00286             62.0
# 10144  U10145             62.0
# 5106   U05107             61.8
# 5937   U05938             61.8
# 8575   U08576             61.8
# 2835   U02836             60.7
# 8454   U08455             60.7
# 9083   U09084             60.7
# 5293   U05294             60.6

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))

plt.bar(
    top10['user_id'],
    top10['influence_score']
)

plt.title('Top 10 Influential Users')
plt.xlabel('User ID')
plt.ylabel('Influence Score')

plt.xticks(rotation=45)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))

sns.heatmap(
    df_processed.corr(numeric_only=True),
    annot=True,
    cmap='coolwarm'
)

plt.title('Correlation Matrix')

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.scatter(
    df_processed['followers'],
    df_processed['influence_score']
)

plt.title('Followers vs Influence Score')
plt.xlabel('Followers')
plt.ylabel('Influence Score')

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.boxplot(df_processed['followers'])

plt.title('Followers Outlier Detection')

plt.ylabel('Followers')

plt.show()

# %%
top_degree = df_processed.nlargest(
    10,
    'degree_centrality'
)

top_degree[
    ['user_id',
     'degree_centrality',
     'influence_score']
]
# Out:
#      user_id  degree_centrality  influence_score
# 69    U00070                1.0             40.6
# 405   U00406                1.0             40.1
# 641   U00642                1.0             56.1
# 1327  U01328                1.0             46.5
# 1574  U01575                1.0             39.6
# 1882  U01883                1.0             51.3
# 1968  U01969                1.0             27.1
# 2216  U02217                1.0             57.3
# 2510  U02511                1.0             56.1
# 3695  U03696                1.0             40.3

# %%
top_between = df_processed.nlargest(
    10,
    'betweenness_centrality'
)

top_between[
    ['user_id',
     'betweenness_centrality',
     'influence_score']
]
# Out:
#       user_id  betweenness_centrality  influence_score
# 10876  U10877                   0.738             51.8
# 11299  U11300                   0.731             55.7
# 10038  U10039                   0.728             46.6
# 2803   U02804                   0.722             28.0
# 2      U00003                   0.719             43.8
# 4556   U04557                   0.713             51.3
# 4231   U04232                   0.711             52.6
# 1680   U01681                   0.706             20.5
# 273    U00274                   0.691             50.5
# 7196   U07197                   0.689             55.7

# %%
import pandas as pd

df = pd.read_csv(
    r"C:\Users\Hp\OneDrive\Desktop\Graph Analytics Project\Dataset\social_influence_dataset.csv"
)

df.head()
# Out:
#   user_id  followers  following  posts  likes_received  comments_received  \
# 0  U00001      44671        733   3070         1781610              27334
# 1  U00002     386989       1197   1768         3995775              91208
# 2  U00003     327303       5957   4453         3041420             166932
# 3  U00004     219467       5696    375         4940929             134407
# 4  U00005     216535       5553   1381         3878565              56525
#
#    mentions  shares  account_age_days region  engagement_rate  \
# 0      6848   25950              4627  South          4294.14
# 1      6979   47510              2590  North          1150.37
# 2      3606   14320               685   East          1184.24
# 3      9217   32757              3652   East          2557.53
# 4      8462   36673              2404  South              NaN
#
#    degree_centrality  betweenness_centrality  influence_score
# 0              0.570                   0.143             17.4
# ...

# %%
df_processed = df.copy()

# %%
top_degree = df_processed.nlargest(
    10,
    'degree_centrality'
)

top_degree[
    ['user_id',
     'degree_centrality',
     'influence_score']
]
# Out:
#      user_id  degree_centrality  influence_score
# 69    U00070                1.0             40.6
# 405   U00406                1.0             40.1
# 641   U00642                1.0             56.1
# 1327  U01328                1.0             46.5
# 1574  U01575                1.0             39.6
# 1882  U01883                1.0             51.3
# 1968  U01969                1.0             27.1
# 2216  U02217                1.0             57.3
# 2510  U02511                1.0             56.1
# 3695  U03696                1.0             40.3

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))

plt.bar(
    top_degree['user_id'],
    top_degree['degree_centrality']
)

plt.title('Top 10 Users by Degree Centrality')
plt.xlabel('User ID')
plt.ylabel('Degree Centrality')

plt.xticks(rotation=45)

plt.show()

# %%
top_between = df_processed.nlargest(
    10,
    'betweenness_centrality'
)

top_between[
    ['user_id',
     'betweenness_centrality',
     'influence_score']
]
# Out:
#       user_id  betweenness_centrality  influence_score
# 10876  U10877                   0.738             51.8
# 11299  U11300                   0.731             55.7
# 10038  U10039                   0.728             46.6
# 2803   U02804                   0.722             28.0
# 2      U00003                   0.719             43.8
# 4556   U04557                   0.713             51.3
# 4231   U04232                   0.711             52.6
# 1680   U01681                   0.706             20.5
# 273    U00274                   0.691             50.5
# 7196   U07197                   0.689             55.7

# %%
plt.figure(figsize=(10,5))

plt.bar(
    top_between['user_id'],
    top_between['betweenness_centrality']
)

plt.title('Top 10 Users by Betweenness Centrality')
plt.xlabel('User ID')
plt.ylabel('Betweenness Centrality')

plt.xticks(rotation=45)

plt.show()

# %%
import pandas as pd

df = pd.read_csv(
    r"C:\Users\Hp\OneDrive\Desktop\Graph Analytics Project\Dataset\social_influence_dataset.csv"
)

df.head()
# Out:
#   user_id  followers  following  posts  likes_received  comments_received  \
# 0  U00001      44671        733   3070         1781610              27334
# 1  U00002     386989       1197   1768         3995775              91208
# 2  U00003     327303       5957   4453         3041420             166932
# 3  U00004     219467       5696    375         4940929             134407
# 4  U00005     216535       5553   1381         3878565              56525
#
#    mentions  shares  account_age_days region  engagement_rate  \
# 0      6848   25950              4627  South          4294.14
# 1      6979   47510              2590  North          1150.37
# 2      3606   14320               685   East          1184.24
# 3      9217   32757              3652   East          2557.53
# 4      8462   36673              2404  South              NaN
#
#    degree_centrality  betweenness_centrality  influence_score
# 0              0.570                   0.143             17.4
# ...

# %%
df_processed = df.copy()

# %%
# !pip install scikit-learn

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.9.0

# %%
from sklearn.model_selection import train_test_split

X = df_processed.drop(
    ['user_id', 'region', 'influence_score'],
    axis=1
)

y = df_processed['influence_score']

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("Training Data Shape:", X_train.shape)
print("Testing Data Shape:", X_test.shape)
# Out:
# Training Data Shape: (9720, 11)
# Testing Data Shape: (2430, 11)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X_train, y_train)

print("Model Training Completed")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 5
#       1 from sklearn.linear_model import LinearRegression
#       2
#       3 model = LinearRegression()
#       4
# ----> 5 model.fit(X_train, y_train)
#       6
#       7 print("Model Training Completed")
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py:681, in LinearRegression.fit(self, X, y, sample_weight)
# ...

# %%
X.isnull().sum()
# Out:
# followers                   0
# following                   0
# posts                       0
# likes_received              0
# comments_received           0
# mentions                    0
# shares                      0
# account_age_days            0
# engagement_rate           306
# degree_centrality           0
# betweenness_centrality      0
# dtype: int64

# %%
X = X.fillna(X.median(numeric_only=True))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X_train, y_train)

print("Model Training Completed")
# Out:
# Model Training Completed

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

print("MAE:", mean_absolute_error(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
print("R² Score:", r2_score(y_test, y_pred))
# Out:
# MAE: 9.301176200272431
# MSE: 122.22881145521623
# R² Score: 0.027020942384117452

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

# %%
rf_model
# Out:
# RandomForestRegressor(random_state=42)

# %%
rf_model.fit(X_train, y_train)

print("Random Forest Model Trained Successfully")
# Out:
# Random Forest Model Trained Successfully

# %%
rf_pred = rf_model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

print("MAE:", mean_absolute_error(y_test, rf_pred))
print("MSE:", mean_squared_error(y_test, rf_pred))
print("R² Score:", r2_score(y_test, rf_pred))
# Out:
# MAE: 0.41077119341563806
# MSE: 0.4613075201646092
# R² Score: 0.996327849785193

# %%
import pandas as pd

feature_importance = pd.DataFrame({
    'Feature': X.columns,
    'Importance': rf_model.feature_importances_
})

feature_importance = feature_importance.sort_values(
    by='Importance',
    ascending=False
)

feature_importance
# Out:
#                    Feature  Importance
# 0                followers    0.815911
# 9        degree_centrality    0.129523
# 10  betweenness_centrality    0.044784
# 8          engagement_rate    0.006551
# 1                following    0.000568
# 6                   shares    0.000479
# 7         account_age_days    0.000468
# 2                    posts    0.000468
# 4        comments_received    0.000454
# 5                 mentions    0.000433
# 3           likes_received    0.000360

# %%
import matplotlib.pyplot as plt

feature_importance.sort_values(
    by='Importance',
    ascending=True
).plot(
    x='Feature',
    y='Importance',
    kind='barh',
    figsize=(8,5)
)

plt.title("Feature Importance - Random Forest")
plt.xlabel("Importance Score")
plt.ylabel("Features")
plt.show()
